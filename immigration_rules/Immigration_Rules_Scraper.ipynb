# %%
import os
import time
import requests
from urllib.parse import urljoin, urlparse
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service

# Setup ChromeDriver
service = Service('/usr/bin/chromedriver')
options = webdriver.ChromeOptions()
# options.add_argument('--headless')  # Enable this if you want headless mode
driver = webdriver.Chrome(service=service, options=options)

# Constants
BASE_URLS = [
    "https://www.irishimmigration.ie/coming-to-visit-ireland/",
    "https://www.irishimmigration.ie/coming-to-study-in-ireland/"
]
OUTPUT_DIR = "ireland-immigration"
VISITED = set()

# Ensure base directory exists
os.makedirs(OUTPUT_DIR, exist_ok=True)

def sanitize_path(url):
    parsed = urlparse(url)
    path = parsed.path.strip("/")
    if not path or path.endswith("/"):
        path += "index"
    path = path.replace("-", "_")
    return os.path.join(OUTPUT_DIR, path)

def normalize_url(url):
    return urljoin("https://www.irishimmigration.ie", url).split("#")[0].rstrip("/")

def is_valid_link(href):
    if not href:
        return False
    abs_url = normalize_url(href)
    return any(abs_url.startswith(base.rstrip("/")) for base in BASE_URLS)

def download_document(url, save_path):
    ext = os.path.splitext(urlparse(url).path)[1]
    if not save_path.endswith(ext):
        save_path += ext

    try:
        r = requests.get(url)
        os.makedirs(os.path.dirname(save_path), exist_ok=True)
        with open(save_path, "wb") as f:
            f.write(r.content)
        print(f"[DOC] {url} -> {save_path}")
    except Exception as e:
        print(f"Download failed: {url} ({e})")

def extract_markdown_from_body(body):
    output = []

    def append_text(tag, prefix=""):
        text = tag.get_text(strip=True)
        if text:
            output.append(f"{prefix}{text}")

    for elem in body.descendants:
        if elem.name in {"script", "style", "noscript"}:
            continue
        if elem.name == "h1":
            append_text(elem, "# ")
        elif elem.name == "h2":
            append_text(elem, "## ")
        elif elem.name == "h3":
            append_text(elem, "### ")
        elif elem.name == "p":
            append_text(elem)
        elif elem.name == "li":
            append_text(elem, "- ")
        elif elem.name == "pre":
            code = elem.get_text().strip()
            output.append("```")
            output.append(code)
            output.append("```")
        elif elem.name == "blockquote":
            append_text(elem, "> ")

    return "\n\n".join(output)

def scrape_page(url):
    norm_url = normalize_url(url)
    if norm_url in VISITED:
        return
    VISITED.add(norm_url)

    driver.get(url)
    time.sleep(1.5)  # Let JavaScript render
    soup = BeautifulSoup(driver.page_source, "html.parser")
    body = soup.body

    if body:
        for tag in body(["script", "style", "noscript"]):
            tag.decompose()
        markdown_text = extract_markdown_from_body(body)

        if markdown_text:
            rel_path = sanitize_path(url) + ".txt"
            os.makedirs(os.path.dirname(rel_path), exist_ok=True)
            with open(rel_path, "w", encoding="utf-8") as f:
                f.write(markdown_text)
            print(f"[PAGE] {url} -> {rel_path}")
        else:
            print(f"No visible text found at {url}")

    # Recurse on links
    for a in soup.find_all("a", href=True):
        href = a["href"]
        abs_url = urljoin(url, href)
        norm_abs_url = normalize_url(abs_url)

        if norm_abs_url in VISITED:
            continue

        if any(abs_url.lower().endswith(ext) for ext in [".pdf"]):
            save_path = sanitize_path(abs_url)
            download_document(abs_url, save_path)
        elif is_valid_link(abs_url):
            scrape_page(abs_url)

# Start crawling
for url in BASE_URLS:
    scrape_page(url)

driver.quit()
# Out:
# [PAGE] https://www.irishimmigration.ie/coming-to-visit-ireland/ -> ireland-immigration/coming_to_visit_ireland.txt
# [PAGE] https://www.irishimmigration.ie/coming-to-study-in-ireland/ -> ireland-immigration/coming_to_study_in_ireland.txt
# [PAGE] https://www.irishimmigration.ie/coming-to-study-in-ireland/study-in-ireland-travel-path/ -> ireland-immigration/coming_to_study_in_ireland/study_in_ireland_travel_path.txt
# [PAGE] https://www.irishimmigration.ie/coming-to-study-in-ireland/what-are-my-study-options/ -> ireland-immigration/coming_to_study_in_ireland/what_are_my_study_options.txt
# [PAGE] https://www.irishimmigration.ie/coming-to-study-in-ireland/what-are-my-study-options/a-third-level-course-or-a-language-course/ -> ireland-immigration/coming_to_study_in_ireland/what_are_my_study_options/a_third_level_course_or_a_language_course.txt
# [PAGE] https://www.irishimmigration.ie/coming-to-study-in-ireland/what-are-my-study-options/interim-list-of-eligible-programmes-ilep/ -> ireland-immigration/coming_to_study_in_ireland/what_are_my_study_options/interim_list_of_eligible_programmes_ilep.txt
# [DOC] https://www.irishimmigration.ie/wp-content/uploads/2025/04/EL-Prog-Criteria-21-March-2025.pdf -> ireland-immigration/wp_content/uploads/2025/04/EL_Prog_Criteria_21_March_2025.pdf
# [DOC] https://www.irishimmigration.ie/wp-content/uploads/2025/04/HE-Prog-Criteria-21-March-2025.pdf -> ireland-immigration/wp_content/uploads/2025/04/HE_Prog_Criteria_21_March_2025.pdf
# [DOC] https://www.irishimmigration.ie/wp-content/uploads/2025/04/Foundation-Criteria-21-March-2025.pdf -> ireland-immigration/wp_content/uploads/2025/04/Foundation_Criteria_21_March_2025.pdf
# [PAGE] https://www.irishimmigration.ie/coming-to-study-in-ireland/what-are-my-study-options/planning-to-study-in-ireland/ -> ireland-immigration/coming_to_study_in_ireland/what_are_my_study_options/planning_to_study_in_ireland.txt
# [PAGE] https://www.irishimmigration.ie/coming-to-study-in-ireland/what-are-my-study-visa-options/how-to-apply-for-long-term-study-visa/ -> ireland-immigration/coming_to_study_in_ireland/what_are_my_study_visa_options/how_to_apply_for_long_term_study_visa.txt
# [PAGE] https://www.irishimmigration.ie/coming-to-study-in-ireland/what-are-my-study-visa-options/ -> ireland-immigration/coming_to_study_in_ireland/what_are_my_study_visa_options.txt
# [PAGE] https://www.irishimmigration.ie/coming-to-study-in-ireland/what-are-my-study-visa-options/how-to-apply-for-a-short-c-visit-study-visa/ -> ireland-immigration/coming_to_study_in_ireland/what_are_my_study_visa_options/how_to_apply_for_a_short_c_visit_study_visa.txt
# [PAGE] https://www.irishimmigration.ie/coming-to-study-in-ireland/what-are-my-study-visa-options/how-to-apply-for-a-short-c-visit-study-visa/school-student-visa-waiver-decision/ -> ireland-immigration/coming_to_study_in_ireland/what_are_my_study_visa_options/how_to_apply_for_a_short_c_visit_study_visa/school_student_visa_waiver_decision.txt
# [DOC] https://www.irishimmigration.ie/wp-content/uploads/2025/03/European-Council-Decision-94-795-JHA.pdf -> ireland-immigration/wp_content/uploads/2025/03/European_Council_Decision_94_795_JHA.pdf
# [PAGE] https://www.irishimmigration.ie/coming-to-visit-ireland/short-stay-visa-waiver-programme/ -> ireland-immigration/coming_to_visit_ireland/short_stay_visa_waiver_programme.txt
# [DOC] https://www.irishimmigration.ie/wp-content/uploads/2023/02/Irish-Short-Stay-Visa-Waiver-Programme-February-2023.pdf -> ireland-immigration/wp_content/uploads/2023/02/Irish_Short_Stay_Visa_Waiver_Programme_February_2023.pdf
# [PAGE] https://www.irishimmigration.ie/coming-to-visit-ireland/british-irish-visa-scheme/ -> ireland-immigration/coming_to_visit_ireland/british_irish_visa_scheme.txt
# [PAGE] https://www.irishimmigration.ie/coming-to-study-in-ireland/policy-on-non-eea-nationals/ -> ireland-immigration/coming_to_study_in_ireland/policy_on_non_eea_nationals.txt
# [DOC] https://www.irishimmigration.ie/wp-content/uploads/2024/12/Guidelines-for-Degree-Programme-Students-January-2011.pdf -> ireland-immigration/wp_content/uploads/2024/12/Guidelines_for_Degree_Programme_Students_January_2011.pdf
# [PAGE] https://www.irishimmigration.ie/coming-to-study-in-ireland/english-language-requirements-for-study-visas/ -> ireland-immigration/coming_to_study_in_ireland/english_language_requirements_for_study_visas.txt
# [PAGE] https://www.irishimmigration.ie/coming-to-study-in-ireland/what-are-my-study-options/a-fee-paying-private-primary-or-secondary-school/information-on-student-finances/ -> ireland-immigration/coming_to_study_in_ireland/what_are_my_study_options/a_fee_paying_private_primary_or_secondary_school/information_on_student_finances.txt
# [PAGE] https://www.irishimmigration.ie/coming-to-study-in-ireland/what-are-my-study-options/a-fee-paying-private-primary-or-secondary-school/ -> ireland-immigration/coming_to_study_in_ireland/what_are_my_study_options/a_fee_paying_private_primary_or_secondary_school.txt
# [PAGE] https://www.irishimmigration.ie/coming-to-study-in-ireland/what-are-my-study-options/a-fee-paying-private-primary-or-secondary-school/private-medical-insurance/ -> ireland-immigration/coming_to_study_in_ireland/what_are_my_study_options/a_fee_paying_private_primary_or_secondary_school/private_medical_insurance.txt
# [PAGE] https://www.irishimmigration.ie/coming-to-study-in-ireland/frequently-asked-questions-for-students/ -> ireland-immigration/coming_to_study_in_ireland/frequently_asked_questions_for_students.txt
# [DOC] https://www.irishimmigration.ie/wp-content/uploads/2023/09/Student-Application-Form-Sep-23.pdf -> ireland-immigration/wp_content/uploads/2023/09/Student_Application_Form_Sep_23.pdf
# [PAGE] https://www.irishimmigration.ie/coming-to-study-in-ireland/what-are-my-study-options/a-short-term-course/ -> ireland-immigration/coming_to_study_in_ireland/what_are_my_study_options/a_short_term_course.txt
# [PAGE] https://www.irishimmigration.ie/coming-to-visit-ireland/how-to-apply-for-a-short-stay-c-visit-tourist-visa/ -> ireland-immigration/coming_to_visit_ireland/how_to_apply_for_a_short_stay_c_visit_tourist_visa.txt
# [PAGE] https://www.irishimmigration.ie/coming-to-visit-ireland/how-to-apply-for-a-short-stay-c-visit-tourist-visa/visit-family-friend-visa/ -> ireland-immigration/coming_to_visit_ireland/how_to_apply_for_a_short_stay_c_visit_tourist_visa/visit_family_friend_visa.txt
# [PAGE] https://www.irishimmigration.ie/coming-to-visit-ireland/visit-ireland-travel-path/ -> ireland-immigration/coming_to_visit_ireland/visit_ireland_travel_path.txt
# [PAGE] https://www.irishimmigration.ie/coming-to-visit-ireland/how-to-apply-for-a-short-stay-c-visit-tourist-visa/marriage-visa/ -> ireland-immigration/coming_to_visit_ireland/how_to_apply_for_a_short_stay_c_visit_tourist_visa/marriage_visa.txt
# [PAGE] https://www.irishimmigration.ie/coming-to-visit-ireland/how-to-apply-for-a-short-stay-c-visit-tourist-visa/short-stay-medical-treatment-visa/ -> ireland-immigration/coming_to_visit_ireland/how_to_apply_for_a_short_stay_c_visit_tourist_visa/short_stay_medical_treatment_visa.txt
# [PAGE] https://www.irishimmigration.ie/coming-to-study-in-ireland/before-and-after-you-arrive/ -> ireland-immigration/coming_to_study_in_ireland/before_and_after_you_arrive.txt
# [PAGE] https://www.irishimmigration.ie/coming-to-study-in-ireland/before-and-after-you-arrive/what-do-i-need-to-do-before-arriving/ -> ireland-immigration/coming_to_study_in_ireland/before_and_after_you_arrive/what_do_i_need_to_do_before_arriving.txt
# [PAGE] https://www.irishimmigration.ie/coming-to-study-in-ireland/before-and-after-you-arrive/what-do-i-need-to-do-after-arriving/ -> ireland-immigration/coming_to_study_in_ireland/before_and_after_you_arrive/what_do_i_need_to_do_after_arriving.txt
# [PAGE] https://www.irishimmigration.ie/coming-to-visit-ireland/giving-your-details-on-avats-for-a-visa-preclearance-application/ -> ireland-immigration/coming_to_visit_ireland/giving_your_details_on_avats_for_a_visa_preclearance_application.txt
# [PAGE] https://www.irishimmigration.ie/coming-to-study-in-ireland/travelling-as-part-of-a-school-tour/ -> ireland-immigration/coming_to_study_in_ireland/travelling_as_part_of_a_school_tour.txt
# [DOC] https://www.irishimmigration.ie/wp-content/uploads/2025/03/European-Council-Decision-94-795-JHA.pdf -> ireland-immigration/wp_content/uploads/2025/03/European_Council_Decision_94_795_JHA.pdf
# [DOC] https://www.irishimmigration.ie/wp-content/uploads/2023/06/Visa-Waiver-for-non-EEA-and-EU-School-Students-v2.pdf -> ireland-immigration/wp_content/uploads/2023/06/Visa_Waiver_for_non_EEA_and_EU_School_Students_v2.pdf
# [PAGE] https://www.irishimmigration.ie/coming-to-study-in-ireland/professional-training-accountancy/ -> ireland-immigration/coming_to_study_in_ireland/professional_training_accountancy.txt
# [PAGE] https://www.irishimmigration.ie/coming-to-visit-ireland/frequently-asked-questions/ -> ireland-immigration/coming_to_visit_ireland/frequently_asked_questions.txt
# [DOC] https://www.irishimmigration.ie/wp-content/uploads/2021/03/Required-documents-Short-Stay-C-Visa.-faq.pdf -> ireland-immigration/wp_content/uploads/2021/03/Required_documents_Short_Stay_C_Visa._faq.pdf
# [DOC] https://www.irishimmigration.ie/wp-content/uploads/2021/03/Additional-Documents-Short-Stay-C-Visa.pdf -> ireland-immigration/wp_content/uploads/2021/03/Additional_Documents_Short_Stay_C_Visa.pdf
# [DOC] https://www.irishimmigration.ie/wp-content/uploads/2021/03/Additional-Documents-Short-Stay-C-Visa.pdf -> ireland-immigration/wp_content/uploads/2021/03/Additional_Documents_Short_Stay_C_Visa.pdf
