# %%
https://www.tcd.ie/study/international/

# %%
import os
import time
import requests
from urllib.parse import urljoin, urlparse
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service

# Setup ChromeDriver
service = Service('/usr/bin/chromedriver')
options = webdriver.ChromeOptions()
# options.add_argument('--headless')  # Enable this if you want headless mode
driver = webdriver.Chrome(service=service, options=options)

# Constants
BASE_URLS = [
    "https://www.tcd.ie/study/international/"
]
OUTPUT_DIR = "./"
VISITED = set()

# Ensure base directory exists
os.makedirs(OUTPUT_DIR, exist_ok=True)

def sanitize_path(url):
    parsed = urlparse(url)
    path = parsed.path.strip("/")
    if not path or path.endswith("/"):
        path += "index"
    path = path.replace("-", "_")
    return os.path.join(OUTPUT_DIR, path)

# This was reused but the result is fine
def normalize_url(url):
    return urljoin("https://erincollege.com/", url).split("#")[0].rstrip("/")

def is_valid_link(href):
    if not href:
        return False
    abs_url = normalize_url(href)
    return any(abs_url.startswith(base.rstrip("/")) for base in BASE_URLS)

def download_document(url, save_path):
    ext = os.path.splitext(urlparse(url).path)[1]
    if not save_path.endswith(ext):
        save_path += ext

    try:
        r = requests.get(url)
        os.makedirs(os.path.dirname(save_path), exist_ok=True)
        with open(save_path, "wb") as f:
            f.write(r.content)
        print(f"[DOC] {url} -> {save_path}")
    except Exception as e:
        print(f"Download failed: {url} ({e})")

def extract_markdown_from_body(body):
    output = []

    def append_text(tag, prefix=""):
        text = tag.get_text(strip=True)
        if text:
            output.append(f"{prefix}{text}")

    for elem in body.descendants:
        if elem.name in {"script", "style", "noscript"}:
            continue
        if elem.name == "h1":
            append_text(elem, "# ")
        elif elem.name == "h2":
            append_text(elem, "## ")
        elif elem.name == "h3":
            append_text(elem, "### ")
        elif elem.name == "p":
            append_text(elem)
        elif elem.name == "li":
            append_text(elem, "- ")
        elif elem.name == "pre":
            code = elem.get_text().strip()
            output.append("```")
            output.append(code)
            output.append("```")
        elif elem.name == "blockquote":
            append_text(elem, "> ")

    return "\n\n".join(output)

def scrape_page(url):
    norm_url = normalize_url(url)
    if norm_url in VISITED:
        return
    VISITED.add(norm_url)

    driver.get(url)
    time.sleep(1.5)  # Let JavaScript render
    soup = BeautifulSoup(driver.page_source, "html.parser")
    body = soup.body

    if body:
        for tag in body(["script", "style", "noscript"]):
            tag.decompose()
        markdown_text = extract_markdown_from_body(body)

        if markdown_text:
            rel_path = sanitize_path(url) + ".txt"
            os.makedirs(os.path.dirname(rel_path), exist_ok=True)
            with open(rel_path, "w", encoding="utf-8") as f:
                f.write(markdown_text)
            print(f"[PAGE] {url} -> {rel_path}")
        else:
            print(f"No visible text found at {url}")

    # Recurse on links
    for a in soup.find_all("a", href=True):
        href = a["href"]
        abs_url = urljoin(url, href)
        norm_abs_url = normalize_url(abs_url)

        if norm_abs_url in VISITED:
            continue

        if any(abs_url.lower().endswith(ext) for ext in [".pdf"]):
            save_path = sanitize_path(abs_url)
            download_document(abs_url, save_path)
        elif is_valid_link(abs_url):
            scrape_page(abs_url)

# Start crawling
for url in BASE_URLS:
    scrape_page(url)

driver.quit()
# Out:
# [PAGE] https://www.tcd.ie/study/international/ -> ./study/international.txt
# [PAGE] https://www.tcd.ie/study/international/why-trinity/ -> ./study/international/why_trinity.txt
# [PAGE] https://www.tcd.ie/study/international/why-trinity/careers -> ./study/international/why_trinity/careers.txt
# [PAGE] https://www.tcd.ie/study/international/why-trinity/location -> ./study/international/why_trinity/location.txt
t
# [PAGE] https://www.tcd.ie/study/international/scholarships/postgraduate/"/lawandbusiness.php" -> ./study/international/scholarships/postgraduate/"/lawandbusiness.php".txt
# [PAGE] https://www.tcd.ie/study/international/assets/forms/PG/MSc Law and Finance Scholarship Application form.doc -> ./study/international/assets/forms/PG/MSc Law and Finance Scholarship Application form.doc.txt
# [PAGE] https://www.tcd.ie/study/international/assets/forms/index.php -> ./study/international/assets/forms/index.php.txt
# No visible text found at https://www.tcd.ie/study/international/assets/index.php
# [PAGE] https://www.tcd.ie/study/international/scholarships/postgraduate/"/socialwork.php" -> ./study/international/scholarships/postgraduate/"/socialwork.php".txt
# [PAGE] https://www.tcd.ie/study/international/scholarships/postgraduate/"/grattanscholars.php" -> ./study/international/scholarships/postgraduate/"/grattanscholars.php".txt
# [PAGE] https://www.tcd.ie/study/international/scholarships/postgraduate/"/hamiltonscholars.php" -> ./study/international/scholarships/postgraduate/"/hamiltonscholars.php".txt
# [PAGE] https://www.tcd.ie/study/international/scholarships/postgraduate/"/victory.php" -> ./study/international/scholarships/postgraduate/"/victory.php".txt
# [PAGE] https://www.tcd.ie/study/international/after-you-arrive/ -> ./study/international/after_you_arrive.txt
# [PAGE] https://www.tcd.ie/study/international/arriving-in-ireland/visa-immigrations/index.php -> ./study/international/arriving_in_ireland/visa_immigrations/index.php.txt
# [PAGE] https://www.tcd.ie/study/international/after-you-arrive/settling-in/index.php -> ./study/international/after_you_arrive/settling_in/index.php.txt
# [PAGE] https://www.tcd.ie/study/international/pre-sesson-programmes/smart-start.php -> ./study/international/pre_sesson_programmes/smart_start.php.txt
# [DOC] https://histories-humanities.tcd.ie/assets/pdf/visiting/smartstartbrochure.pdf -> ./assets/pdf/visiting/smartstartbrochure.pdf
# [PAGE] https://www.tcd.ie/study/international/after-you-arrive/life-admin/index.php -> ./study/international/after_you_arrive/life_admin/index.php.txt
# [PAGE] https://www.tcd.ie/study/international/student-experience/supports-services -> ./study/international/student_experience/supports_services.txt
# [PAGE] https://www.tcd.ie/study/international/how-to-apply/index.php -> ./study/international/how_to_apply/index.php.txt
# [PAGE] https://www.tcd.ie/study/international/foundation-programme/index.php -> ./study/international/foundation_programme/index.php.txt
# [PAGE] https://www.tcd.ie/study/international/foundation-programme/pathways.php -> ./study/international/foundation_programme/pathways.php.txt
# [PAGE] https://www.tcd.ie/study/international/foundation-programme/pathwaya.php -> ./study/international/foundation_programme/pathwaya.php.txt
# [PAGE] https://www.tcd.ie/study/international/foundation-programme/pathwayb.php -> ./study/international/foundation_programme/pathwayb.php.txt
# [PAGE] https://www.tcd.ie/study/international/foundation-programme/faq.php -> ./study/international/foundation_programme/faq.php.txt
# [PAGE] https://www.tcd.ie/study/international/foundation-programme/entry.php -> ./study/international/foundation_programme/entry.php.txt
# [PAGE] https://www.tcd.ie/study/international/foundation-programme/howitworks.php -> ./study/international/foundation_programme/howitworks.php.txt
# [PAGE] https://www.tcd.ie/study/international/foundation-programme/fees.php -> ./study/international/foundation_programme/fees.php.txt
# [PAGE] https://www.tcd.ie/study/international/foundation-programme/scholarships/ifp-scholarship.php -> ./study/international/foundation_programme/scholarships/ifp_scholarship.php.txt
# [PAGE] https://www.tcd.ie/study/international/foundation-programme/scholarships/china-claddagh.php -> ./study/international/foundation_programme/scholarships/china_claddagh.php.txt
# [PAGE] https://www.tcd.ie/study/international/foundation-programme/scholarships/japanese-students.php -> ./study/international/foundation_programme/scholarships/japanese_students.php.txt
# [PAGE] https://www.tcd.ie/study/international/foundation-programme/scholarships/Joint-IFP-Freshman-E3.php -> ./study/international/foundation_programme/scholarships/Joint_IFP_Freshman_E3.php.txt
# [PAGE] https://www.tcd.ie/study/international/how-to-apply/entry-requirements.php -> ./study/international/how_to_apply/entry_requirements.php.txt
# [PAGE] https://www.tcd.ie/study/international/how-to-apply/ug-pathway.php -> ./study/international/how_to_apply/ug_pathway.php.txt
# [PAGE] https://www.tcd.ie/study/international/how-to-apply/pg-pathway.php -> ./study/international/how_to_apply/pg_pathway.php.txt
# [PAGE] https://www.tcd.ie/study/international/why-trinity/careers.php -> ./study/international/why_trinity/careers.php.txt
# [PAGE] https://www.tcd.ie/study/international/foundation-programme/ -> ./study/international/foundation_programme.txt
# [PAGE] https://www.tcd.ie/study/international/pre-sesson-programmes/index.php -> ./study/international/pre_sesson_programmes/index.php.txt

# %%
# !ls
# Out:
# Junior_Dean  TCD.ipynb	assets	study  wp_content
