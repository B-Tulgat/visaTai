# %%
https://www.ucc.ie/en/international/

# %%
import os
import time
import requests
from urllib.parse import urljoin, urlparse
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service

# Setup ChromeDriver
service = Service('/usr/bin/chromedriver')
options = webdriver.ChromeOptions()
options.add_argument('--headless')
driver = webdriver.Chrome(service=service, options=options)

# Constants
BASE_URLS = [
    "https://www.ucc.ie/en/international/studyatucc/",
    "https://www.ucc.ie/en/ck202/",
    "https://www.ucc.ie/en/ckl26/",
    "https://www.ucc.ie/en/ckr49/",
    "https://www.ucc.ie/en/ck411/",
    "https://www.ucc.ie/en/ck401/",
    "https://www.ucc.ie/en/ckr02/",
    "https://www.ucc.ie/en/ckl06/"
]
OUTPUT_DIR = "./"
VISITED = set()

# Ensure base directory exists
os.makedirs(OUTPUT_DIR, exist_ok=True)

def sanitize_path(url):
    parsed = urlparse(url)
    path = parsed.path.strip("/")
    if not path or path.endswith("/"):
        path += "index"
    path = path.replace("-", "_")
    return os.path.join(OUTPUT_DIR, path)

# This was reused but the result is fine
def normalize_url(url):
    return urljoin("https://erincollege.com/", url).split("#")[0].rstrip("/")

def is_valid_link(href):
    if not href:
        return False
    abs_url = normalize_url(href)
    return any(abs_url.startswith(base.rstrip("/")) for base in BASE_URLS)

def download_document(url, save_path):
    ext = os.path.splitext(urlparse(url).path)[1]
    if not save_path.endswith(ext):
        save_path += ext

    try:
        r = requests.get(url)
        os.makedirs(os.path.dirname(save_path), exist_ok=True)
        with open(save_path, "wb") as f:
            f.write(r.content)
        print(f"[DOC] {url} -> {save_path}")
    except Exception as e:
        print(f"Download failed: {url} ({e})")

def extract_markdown_from_body(body):
    output = []

    def append_text(tag, prefix=""):
        text = tag.get_text(strip=True)
        if text:
            output.append(f"{prefix}{text}")

    for elem in body.descendants:
        if elem.name in {"script", "style", "noscript"}:
            continue
        if elem.name == "h1":
            append_text(elem, "# ")
        elif elem.name == "h2":
            append_text(elem, "## ")
        elif elem.name == "h3":
            append_text(elem, "### ")
        elif elem.name == "p":
            append_text(elem)
        elif elem.name == "li":
            append_text(elem, "- ")
        elif elem.name == "pre":
            code = elem.get_text().strip()
            output.append("```")
            output.append(code)
            output.append("```")
        elif elem.name == "blockquote":
            append_text(elem, "> ")

    return "\n\n".join(output)

def scrape_page(url):
    norm_url = normalize_url(url)
    if norm_url in VISITED:
        return
    VISITED.add(norm_url)

    driver.get(url)
    time.sleep(0.5)  # Let JavaScript render
    soup = BeautifulSoup(driver.page_source, "html.parser")
    body = soup.body

    if body:
        for tag in body(["script", "style", "noscript"]):
            tag.decompose()
        markdown_text = extract_markdown_from_body(body)

        if markdown_text:
            rel_path = sanitize_path(url) + ".txt"
            os.makedirs(os.path.dirname(rel_path), exist_ok=True)
            with open(rel_path, "w", encoding="utf-8") as f:
                f.write(markdown_text)
            print(f"[PAGE] {url} -> {rel_path}")
        else:
            print(f"No visible text found at {url}")

    # Recurse on links
    for a in soup.find_all("a", href=True):
        href = a["href"]
        abs_url = urljoin(url, href)
        norm_abs_url = normalize_url(abs_url)

        if norm_abs_url in VISITED:
            continue

        if any(abs_url.lower().endswith(ext) for ext in [".pdf"]):
            save_path = sanitize_path(abs_url)
            download_document(abs_url, save_path)
        elif is_valid_link(abs_url):
            scrape_page(abs_url)

# Start crawling
for url in BASE_URLS:
    scrape_page(url)

driver.quit()
# Out:
# [PAGE] https://www.ucc.ie/en/international/studyatucc/ -> ./en/international/studyatucc.txt
# [PAGE] https://www.ucc.ie/en/international/studyatucc/undergraduateprogrammes/ -> ./en/international/studyatucc/undergraduateprogrammes.txt
# [PAGE] https://www.ucc.ie/en/international/studyatucc/postgraduateprogrammes/ -> ./en/international/studyatucc/postgraduateprogrammes.txt
# [PAGE] https://www.ucc.ie/en/international/studyatucc/incomingerasmusstudents/ -> ./en/international/studyatucc/incomingerasmusstudents.txt
# [PAGE] https://www.ucc.ie/en/international/studyatucc/visitingusandnoneustudents/ -> ./en/international/studyatucc/visitingusandnoneustudents.txt
# [PAGE] https://www.ucc.ie/en/international/studyatucc/visitingusandnoneustudents/howdoiapply/ -> ./en/international/studyatucc/visitingusandnoneustudents/howdoiapply.txt
# [PAGE] https://www.ucc.ie/en/international/studyatucc/visitingusandnoneustudents/howdoiapply/ Book%20of%20Modules%20for%20Visiting%20Students -> ./en/international/studyatucc/visitingusandnoneustudents/howdoiapply/ Book%20of%20Modules%20for%20Visiting%20Students.txt
# [PAGE] https://www.ucc.ie/en/international/studyatucc/visitingusandnoneustudents/whatcanistudy/ -> ./en/international/studyatucc/visitingusandnoneustudents/whatcanistudy.txt
# [PAGE] https://www.ucc.ie/en/international/studyatucc/visitingusandnoneustudents/autumn/ -> ./en/international/studyatucc/visitingusandnoneustudents/autumn.txt
# [PAGE] https://www.ucc.ie/en/international/studyatucc/visitingusandnoneustudents/  -> ./en/international/studyatucc/visitingusandnoneustudents/ .txt
# [PAGE] https://www.ucc.ie/en/international/studyatucc/visitingusandnoneustudents/earlystartprogramme/ -> ./en/international/studyatucc/visitingusandnoneustudents/earlystartprogramme.txt
# [PAGE] https://www.ucc.ie/en/international/studyatucc/visitingusandnoneustudents/esarch/ -> ./en/international/studyatucc/visitingusandnoneustudents/esarch.txt
# [PAGE] https://www.ucc.ie/en/international/studyatucc/visitingusandnoneustudents/eshistory/ -> ./en/international/studyatucc/visitingusandnoneustudents/eshistory.txt
# [PAGE] https://www.ucc.ie/en/international/studyatucc/visitingusandnoneustudents/eshistory/www.ucc.ie  -> ./en/international/studyatucc/visitingusandnoneustudents/eshistory/www.ucc.ie .txt
# [PAGE] https://www.ucc.ie/en/international/studyatucc/visitingusandnoneustudents/entryrequirements/ -> ./en/international/studyatucc/visitingusandnoneustudents/entryrequirements.txt
# [PAGE] https://www.ucc.ie/en/international/studyatucc/visitingusandnoneustudents/housingandlivinginireland/ -> ./en/international/studyatucc/visitingusandnoneustudents/housingandlivinginireland.txt
# [PAGE] https://www.ucc.ie/en/international/studyatucc/visitingusandnoneustudents/semesterdates/ -> ./en/international/studyatucc/visitingusandnoneustudents/semesterdates.txt
# [PAGE] https://www.ucc.ie/en/international/studyatucc/visitingusandnoneustudents/whatwillitcost/ -> ./en/international/studyatucc/visitingusandnoneustudents/whatwillitcost.txt
# [PAGE] https://www.ucc.ie/en/international/studyatucc/visitingusandnoneustudents/examsandacademictranscripts/ -> ./en/international/studyatucc/visitingusandnoneustudents/examsandacademictranscripts.txt
# [PAGE] https://www.ucc.ie/en/international/studyatucc/visitingusandnoneustudents/contactus/ -> ./en/international/studyatucc/visitingusandnoneustudents/contactus.txt
# [PAGE] https://www.ucc.ie/en/international/studyatucc/visitingeustudents/ -> ./en/international/studyatucc/visitingeustudents.txt
# [PAGE] https://www.ucc.ie/en/international/studyatucc/scholarshipsandfunding/ -> ./en/international/studyatucc/scholarshipsandfunding.txt
# [PAGE] https://www.ucc.ie/en/international/studyatucc/uccsummerschoolsnew/ -> ./en/international/studyatucc/uccsummerschoolsnew.txt
# [PAGE] https://www.ucc.ie/en/international/studyatucc/euornoneuundergraduate/ -> ./en/international/studyatucc/euornoneuundergraduate.txt
# [PAGE] https://www.ucc.ie/en/international/studyatucc/visitingeustudents/certirish/ -> ./en/international/studyatucc/visitingeustudents/certirish.txt
# [DOC] https://www.ucc.ie/en/media/studyatucc/international/documentation/incomingerasmusstudents/EstimatedCostofLivinginCork2023.pdf -> ./en/media/studyatucc/international/documentation/incomingerasmusstudents/EstimatedCostofLivinginCork2023.pdf
# [DOC] https://www.ucc.ie/en/media/studyatucc/international/documentation/incomingerasmusstudents/EstimatedCostofLivinginCork2023.pdf -> ./en/media/studyatucc/international/documentation/incomingerasmusstudents/EstimatedCostofLivinginCork2023.pdf
# [DOC] https://www.ucc.ie/en/media/studyatucc/international/V4NorthAmericanBrochureMCDIGITAL.pdf -> ./en/media/studyatucc/international/V4NorthAmericanBrochureMCDIGITAL.pdf
# [DOC] https://www.ucc.ie/en/media/studyatucc/international/documentation/visitingusandnon-eustudents/VisitingStudentFactSheet(1).pdf -> ./en/media/studyatucc/international/documentation/visitingusandnon_eustudents/VisitingStudentFactSheet(1).pdf
# [PAGE] https://www.ucc.ie/en/international/studyatucc/visitingusandnoneustudents/fullyear/ -> ./en/international/studyatucc/visitingusandnoneustudents/fullyear.txt
# [PAGE] https://www.ucc.ie/en/international/studyatucc/visitingusandnoneustudents/esfull/ -> ./en/international/studyatucc/visitingusandnoneustudents/esfull.txt
# [PAGE] https://www.ucc.ie/en/international/studyatucc/visitingusandnoneustudents/esfull/www.ucc.ie  -> ./en/international/studyatucc/visitingusandnoneustudents/esfull/www.ucc.ie .txt
# [PAGE] https://www.ucc.ie/en/international/studyatucc/visitingusandnoneustudents/dipcleu/#d.en.827813 -> ./en/international/studyatucc/visitingusandnoneustudents/dipcleu.txt
# [PAGE] https://www.ucc.ie/en/international/studyatucc/visitingusandnoneustudents/spring/ -> ./en/international/studyatucc/visitingusandnoneustudents/spring.txt
# [DOC] https://www.ucc.ie/en/media/studyatucc/international/V4NorthAmericanBrochureMCDIGITAL.pdf -> ./en/media/studyatucc/international/V4NorthAmericanBrochureMCDIGITAL.pdf
# [DOC] https://www.ucc.ie/en/media/studyatucc/international/documentation/visitingusandnon-eustudents/VisitingStudentFactSheet(1).pdf -> ./en/media/studyatucc/international/documentation/visitingusandnon_eustudents/VisitingStudentFactSheet(1).pdf
# [DOC] https://www.ucc.ie/en/media/studyatucc/international/documentation/UniversityCollegeCorkFactSheet2024-2025(1).pdf -> ./en/media/studyatucc/international/documentation/UniversityCollegeCorkFactSheet2024_2025(1).pdf
# [PAGE] https://www.ucc.ie/en/international/studyatucc/visitingusandnoneustudents/certirish/ -> ./en/international/studyatucc/visitingusandnoneustudents/certirish.txt
# [DOC] https://www.ucc.ie/en/media/studyatucc/international/documentation/visitingusandnon-eustudents/Onlineenrolmentandmoduleregistration.pdf -> ./en/media/studyatucc/international/documentation/visitingusandnon_eustudents/Onlineenrolmentandmoduleregistration.pdf
# [DOC] https://www.ucc.ie/en/media/studyatucc/international/documentation/visitingusandnon-eustudents/FinalExaminationResults.pdf -> ./en/media/studyatucc/international/documentation/visitingusandnon_eustudents/FinalExaminationResults.pdf
# [DOC] https://www.ucc.ie/en/media/studyatucc/international/documentation/visitingusandnon-eustudents/UCCAcademicTranscriptInformation.pdf -> ./en/media/studyatucc/international/documentation/visitingusandnon_eustudents/UCCAcademicTranscriptInformation.pdf
# [DOC] https://www.ucc.ie/en/media/studyatucc/international/documentation/incomingerasmusstudents/EstimatedCostofLivinginCork2023.pdf -> ./en/media/studyatucc/international/documentation/incomingerasmusstudents/EstimatedCostofLivinginCork2023.pdf
# [PAGE] https://www.ucc.ie/en/international/studyatucc/postgraduateprogrammes/taughtprogrammes-non-eu/ -> ./en/international/studyatucc/postgraduateprogrammes/taughtprogrammes_non_eu.txt
# [PAGE] https://www.ucc.ie/en/international/studyatucc/postgraduateprogrammes/taughtprogrammes-non-eu/programmes/ -> ./en/international/studyatucc/postgraduateprogrammes/taughtprogrammes_non_eu/programmes.txt
# [PAGE] https://www.ucc.ie/en/international/studyatucc/postgraduateprogrammes/taughtprogrammes-non-eu/non-eupostgraduateapplicationsoffers/ -> ./en/international/studyatucc/postgraduateprogrammes/taughtprogrammes_non_eu/non_eupostgraduateapplicationsoffers.txt
# [PAGE] https://www.ucc.ie/en/international/studyatucc/postgraduateprogrammes/euornoneupostgraduate/ -> ./en/international/studyatucc/postgraduateprogrammes/euornoneupostgraduate.txt
# [PAGE] https://www.ucc.ie/en/international/studyatucc/postgraduateprogrammes/taughtprogrammes-non-eu/englishlanguageentryrequirements/ -> ./en/international/studyatucc/postgraduateprogrammes/taughtprogrammes_non_eu/englishlanguageentryrequirements.txt
# [PAGE] https://www.ucc.ie/en/international/studyatucc/postgraduateprogrammes/taughtprogrammes-non-eu/feespayment/ -> ./en/international/studyatucc/postgraduateprogrammes/taughtprogrammes_non_eu/feespayment.txt
# [PAGE] https://www.ucc.ie/en/international/studyatucc/postgraduateprogrammes/taughtprogrammes-non-eu/registrationandorientation/ -> ./en/international/studyatucc/postgraduateprogrammes/taughtprogrammes_non_eu/registrationandorientation.txt
# [PAGE] https://www.ucc.ie/en/international/studyatucc/postgraduateprogrammes/taughtprogrammes-non-eu/livinginireland/ -> ./en/international/studyatucc/postgraduateprogrammes/taughtprogrammes_non_eu/livinginireland.txt
# [PAGE] https://www.ucc.ie/en/international/studyatucc/postgraduateprogrammes/researchprogrammes/ -> ./en/international/studyatucc/postgraduateprogrammes/researchprogrammes.txt
# [DOC] https://www.ucc.ie/en/media/studyatucc/international/documentation/postgraduatenon-eustudents/pdfs/UCCApprovedAgentListing10122020.pdf -> ./en/media/studyatucc/international/documentation/postgraduatenon_eustudents/pdfs/UCCApprovedAgentListing10122020.pdf
# [PAGE] https://www.ucc.ie/en/international/studyatucc/undergraduateprogrammes/euornoneuundergraduate/#d.en.820132 -> ./en/international/studyatucc/undergraduateprogrammes/euornoneuundergraduate.txt
# [DOC] https://www.ucc.ie/en/media/studyatucc/international/documentation/undergraduatenon-eustudents/UCCUndergraduateBands2025-2026.pdf -> ./en/media/studyatucc/international/documentation/undergraduatenon_eustudents/UCCUndergraduateBands2025_2026.pdf
# [DOC] https://www.ucc.ie/en/media/studyatucc/international/documentation/undergraduatenon-eustudents/UGMinimumALevelsGrades2025-2026WebsiteVersion.pdf -> ./en/media/studyatucc/international/documentation/undergraduatenon_eustudents/UGMinimumALevelsGrades2025_2026WebsiteVersion.pdf
# [DOC] https://www.ucc.ie/en/media/studyatucc/international/documentation/undergraduatenon-eustudents/UGMinimumIBPoints2025-2026WebsiteVersion.pdf -> ./en/media/studyatucc/international/documentation/undergraduatenon_eustudents/UGMinimumIBPoints2025_2026WebsiteVersion.pdf
# [PAGE] https://www.ucc.ie/en/ck202/ -> ./en/ck202.txt
# [PAGE] https://www.ucc.ie/en/ck202/studenttestimonials/#d.en.888735 -> ./en/ck202/studenttestimonials.txt
# [DOC] https://www.cpaireland.ie/CPAIreland/media/Business-Development/College-Exemptions_3.pdf -> ./CPAIreland/media/Business_Development/College_Exemptions_3.pdf
# [PAGE] https://www.ucc.ie/en/ckl26/ -> ./en/ckl26.txt
# [PAGE] https://www.ucc.ie/en/ckr49/ -> ./en/ckr49.txt
# [PAGE] https://www.ucc.ie/en/ck411/ -> ./en/ck411.txt
# [PAGE] https://www.ucc.ie/en/ck401/ -> ./en/ck401.txt
# [PAGE] https://www.ucc.ie/en/ckr02/ -> ./en/ckr02.txt
# [PAGE] https://www.ucc.ie/en/ckl06/ -> ./en/ckl06.txt
