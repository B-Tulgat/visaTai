# %%
https://www.griffith.ie/global/study-at-griffith/

# %%
import os
import time
import requests
from urllib.parse import urljoin, urlparse
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service

# Setup ChromeDriver
service = Service('/usr/bin/chromedriver')
options = webdriver.ChromeOptions()
# options.add_argument('--headless')  # Enable this if you want headless mode
driver = webdriver.Chrome(service=service, options=options)

# Constants
BASE_URLS = [
    "https://www.griffith.ie/global/study-at-griffith/"
]
OUTPUT_DIR = "./"
VISITED = set()

# Ensure base directory exists
os.makedirs(OUTPUT_DIR, exist_ok=True)

def sanitize_path(url):
    parsed = urlparse(url)
    path = parsed.path.strip("/")
    if not path or path.endswith("/"):
        path += "index"
    path = path.replace("-", "_")
    return os.path.join(OUTPUT_DIR, path)

# This was reused but the result is fine
def normalize_url(url):
    return urljoin("https://erincollege.com/", url).split("#")[0].rstrip("/")

def is_valid_link(href):
    if not href:
        return False
    abs_url = normalize_url(href)
    return any(abs_url.startswith(base.rstrip("/")) for base in BASE_URLS)

def download_document(url, save_path):
    ext = os.path.splitext(urlparse(url).path)[1]
    if not save_path.endswith(ext):
        save_path += ext

    try:
        r = requests.get(url)
        os.makedirs(os.path.dirname(save_path), exist_ok=True)
        with open(save_path, "wb") as f:
            f.write(r.content)
        print(f"[DOC] {url} -> {save_path}")
    except Exception as e:
        print(f"Download failed: {url} ({e})")

def extract_markdown_from_body(body):
    output = []

    def append_text(tag, prefix=""):
        text = tag.get_text(strip=True)
        if text:
            output.append(f"{prefix}{text}")

    for elem in body.descendants:
        if elem.name in {"script", "style", "noscript"}:
            continue
        if elem.name == "h1":
            append_text(elem, "# ")
        elif elem.name == "h2":
            append_text(elem, "## ")
        elif elem.name == "h3":
            append_text(elem, "### ")
        elif elem.name == "p":
            append_text(elem)
        elif elem.name == "li":
            append_text(elem, "- ")
        elif elem.name == "pre":
            code = elem.get_text().strip()
            output.append("```")
            output.append(code)
            output.append("```")
        elif elem.name == "blockquote":
            append_text(elem, "> ")

    return "\n\n".join(output)

def scrape_page(url):
    norm_url = normalize_url(url)
    if norm_url in VISITED:
        return
    VISITED.add(norm_url)

    driver.get(url)
    time.sleep(1.5)  # Let JavaScript render
    soup = BeautifulSoup(driver.page_source, "html.parser")
    body = soup.body

    if body:
        for tag in body(["script", "style", "noscript"]):
            tag.decompose()
        markdown_text = extract_markdown_from_body(body)

        if markdown_text:
            rel_path = sanitize_path(url) + ".txt"
            os.makedirs(os.path.dirname(rel_path), exist_ok=True)
            with open(rel_path, "w", encoding="utf-8") as f:
                f.write(markdown_text)
            print(f"[PAGE] {url} -> {rel_path}")
        else:
            print(f"No visible text found at {url}")

    # Recurse on links
    for a in soup.find_all("a", href=True):
        href = a["href"]
        abs_url = urljoin(url, href)
        norm_abs_url = normalize_url(abs_url)

        if norm_abs_url in VISITED:
            continue

        if any(abs_url.lower().endswith(ext) for ext in [".pdf"]):
            save_path = sanitize_path(abs_url)
            download_document(abs_url, save_path)
        elif is_valid_link(abs_url):
            scrape_page(abs_url)

# Start crawling
for url in BASE_URLS:
    scrape_page(url)

driver.quit()
# Out:
# [PAGE] https://www.griffith.ie/global/study-at-griffith/ -> ./global/study_at_griffith.txt
# [PAGE] https://www.griffith.ie/global/study-at-griffith/courses -> ./global/study_at_griffith/courses.txt
# [PAGE] https://www.griffith.ie/global/study-at-griffith/how-apply -> ./global/study_at_griffith/how_apply.txt
# [PAGE] https://www.griffith.ie/global/study-at-griffith/meet-the-team -> ./global/study_at_griffith/meet_the_team.txt
# [PAGE] https://www.griffith.ie/global/study-at-griffith/english-language-entry-requirements -> ./global/study_at_griffith/english_language_entry_requirements.txt
# [PAGE] https://www.griffith.ie/global/study-at-griffith/visa-information -> ./global/study_at_griffith/visa_information.txt
# [PAGE] https://www.griffith.ie/global/study-at-griffith/faqs-and-policies -> ./global/study_at_griffith/faqs_and_policies.txt
# [PAGE] https://www.griffith.ie/global/study-at-griffith/goi-ies -> ./global/study_at_griffith/goi_ies.txt
# [DOC] https://www.griffith.ie/sites/default/files/2025-02/griffith-college-safety-statement.pdf -> ./sites/default/files/2025_02/griffith_college_safety_statement.pdf
# [DOC] https://www.griffith.ie/sites/default/files/2024-12/fee-information-pack.pdf -> ./sites/default/files/2024_12/fee_information_pack.pdf
# [DOC] https://qrfy.io/api/storage/gcs/pdf/qrfyprod/92a335c5-d74b-4646-93c7-38c7f0dbe286.pdf -> ./api/storage/gcs/pdf/qrfyprod/92a335c5_d74b_4646_93c7_38c7f0dbe286.pdf
# [DOC] https://qrfy.io/api/storage/gcs/pdf/qrfyprod/30ba5f34-d5eb-4dee-b47c-4b2b3978c806.pdf -> ./api/storage/gcs/pdf/qrfyprod/30ba5f34_d5eb_4dee_b47c_4b2b3978c806.pdf
# [DOC] https://qrfy.io/api/storage/gcs/pdf/qrfyprod/30ba5f34-d5eb-4dee-b47c-4b2b3978c806.pdf -> ./api/storage/gcs/pdf/qrfyprod/30ba5f34_d5eb_4dee_b47c_4b2b3978c806.pdf
# [DOC] https://www.griffith.ie/sites/default/files/2024-12/fee-information-pack.pdf -> ./sites/default/files/2024_12/fee_information_pack.pdf
# [DOC] https://qrfy.io/api/storage/gcs/pdf/qrfyprod/aa06421e-dd97-4aa7-add5-1f080eeb4ac9.pdf -> ./api/storage/gcs/pdf/qrfyprod/aa06421e_dd97_4aa7_add5_1f080eeb4ac9.pdf
# [DOC] https://qrfy.io/api/storage/gcs/pdf/qrfyprod/047a191d-f26f-4593-ace2-50b70c6c06be.pdf -> ./api/storage/gcs/pdf/qrfyprod/047a191d_f26f_4593_ace2_50b70c6c06be.pdf
# [DOC] https://www.griffith.ie/sites/default/files/2025-02/griffith-college-safety-statement.pdf -> ./sites/default/files/2025_02/griffith_college_safety_statement.pdf
# [DOC] https://www.griffith.ie/sites/default/files/2025-02/griffith-college-safety-statement.pdf -> ./sites/default/files/2025_02/griffith_college_safety_statement.pdf
# [DOC] https://www.griffith.ie/sites/default/files/2025-02/griffith-college-safety-statement.pdf -> ./sites/default/files/2025_02/griffith_college_safety_statement.pdf
# [DOC] https://www.griffith.ie/sites/default/files/2025-02/griffith-college-safety-statement.pdf -> ./sites/default/files/2025_02/griffith_college_safety_statement.pdf
# [DOC] https://www.griffith.ie/sites/default/files/2025-02/griffith-college-safety-statement.pdf -> ./sites/default/files/2025_02/griffith_college_safety_statement.pdf
# [DOC] https://www.griffith.ie/sites/default/files/2023-05/llb-12082022-compressed-v3.pdf -> ./sites/default/files/2023_05/llb_12082022_compressed_v3.pdf
# [DOC] https://www.griffith.ie/sites/default/files/2023-05/graphic-designer-v2.pdf -> ./sites/default/files/2023_05/graphic_designer_v2.pdf
# [DOC] https://www.griffith.ie/sites/default/files/2023-03/bschonscs-14102022-compressed.pdf -> ./sites/default/files/2023_03/bschonscs_14102022_compressed.pdf
# [DOC] https://www.griffith.ie/sites/default/files/2024-06/b.a-hons-psychology-prospectus-v4.2-27062024.pdf -> ./sites/default/files/2024_06/b.a_hons_psychology_prospectus_v4.2_27062024.pdf
# [DOC] https://www.griffith.ie/sites/default/files/2023-05/mba-14122022-compressed.pdf -> ./sites/default/files/2023_05/mba_14122022_compressed.pdf
# [DOC] https://www.griffith.ie/sites/default/files/2023-05/mscpbm-compressed-v2.pdf -> ./sites/default/files/2023_05/mscpbm_compressed_v2.pdf
# [DOC] https://www.griffith.ie/sites/default/files/2023-05/mscpbt-compressed-v2.pdf -> ./sites/default/files/2023_05/mscpbt_compressed_v2.pdf
# [DOC] https://www.griffith.ie/sites/default/files/2023-05/mscdt-brochure-v3-forview.pdf -> ./sites/default/files/2023_05/mscdt_brochure_v3_forview.pdf
# [DOC] https://www.griffith.ie/sites/default/files/2023-06/mscmdtb-brochure-forview-v4.pdf -> ./sites/default/files/2023_06/mscmdtb_brochure_forview_v4.pdf
# [DOC] https://www.griffith.ie/sites/default/files/2024-02/childhood-adolescence-programmes-v4-16022024.pdf -> ./sites/default/files/2024_02/childhood_adolescence_programmes_v4_16022024.pdf
# [DOC] https://www.griffith.ie/sites/default/files/2024-02/childhood-adolescence-programmes-v4-16022024.pdf -> ./sites/default/files/2024_02/childhood_adolescence_programmes_v4_16022024.pdf
# [DOC] https://www.griffith.ie/sites/default/files/2024-02/childhood-adolescence-programmes-v4-16022024.pdf -> ./sites/default/files/2024_02/childhood_adolescence_programmes_v4_16022024.pdf
# [DOC] https://www.griffith.ie/sites/default/files/2024-02/psychology-behavioural-science-programmes-v4-16022024.pdf -> ./sites/default/files/2024_02/psychology_behavioural_science_programmes_v4_16022024.pdf
# [DOC] https://www.griffith.ie/sites/default/files/2024-02/psychology-behavioural-science-programmes-v4-16022024.pdf -> ./sites/default/files/2024_02/psychology_behavioural_science_programmes_v4_16022024.pdf
# [DOC] https://www.griffith.ie/sites/default/files/2024-02/psychology-behavioural-science-programmes-v4-16022024.pdf -> ./sites/default/files/2024_02/psychology_behavioural_science_programmes_v4_16022024.pdf
# [DOC] https://www.griffith.ie/sites/default/files/2024-02/psychology-behavioural-science-programmes-v4-16022024.pdf -> ./sites/default/files/2024_02/psychology_behavioural_science_programmes_v4_16022024.pdf
# [DOC] https://www.griffith.ie/sites/default/files/2024-02/psychology-behavioural-science-programmes-v4-16022024.pdf -> ./sites/default/files/2024_02/psychology_behavioural_science_programmes_v4_16022024.pdf
# [DOC] https://www.griffith.ie/sites/default/files/2024-02/addiction-recovery-programmes-v3-19022024.pdf -> ./sites/default/files/2024_02/addiction_recovery_programmes_v3_19022024.pdf
# [DOC] https://www.griffith.ie/sites/default/files/2024-02/addiction-recovery-programmes-v3-19022024.pdf -> ./sites/default/files/2024_02/addiction_recovery_programmes_v3_19022024.pdf
# [DOC] https://www.griffith.ie/sites/default/files/2023-03/foundation-27022023-print-compressed.pdf -> ./sites/default/files/2023_03/foundation_27022023_print_compressed.pdf
# [DOC] https://www.griffith.ie/sites/default/files/2025-02/non-eu-quick-programme-guide-v21.3-24022025-clickable.pdf -> ./sites/default/files/2025_02/non_eu_quick_programme_guide_v21.3_24022025_clickable.pdf
# [DOC] https://www.griffith.ie/sites/default/files/2025-02/griffith-college-safety-statement.pdf -> ./sites/default/files/2025_02/griffith_college_safety_statement.pdf
# [DOC] https://www.griffith.ie/sites/default/files/2025-06/non-eu-quick-programme-guide-v22.1-10062025-clickable.pdf -> ./sites/default/files/2025_06/non_eu_quick_programme_guide_v22.1_10062025_clickable.pdf
# [DOC] https://www.griffith.ie/sites/default/files/2025-06/eu-quick-programme-guide-v18-09062025-clickable.pdf -> ./sites/default/files/2025_06/eu_quick_programme_guide_v18_09062025_clickable.pdf
# [DOC] https://www.griffith.ie/sites/default/files/2025-02/griffith-college-safety-statement.pdf -> ./sites/default/files/2025_02/griffith_college_safety_statement.pdf
